# %%
import pandas as pd
import numpy as np
import statistics

# %%
data = pd.read_csv("country_vaccination_stats.csv")

# %%
data.columns
# Out:
# Index(['country', 'date', 'daily_vaccinations', 'vaccines'], dtype='object')

# %%
data.head()
# Out:
#      country        date  daily_vaccinations   vaccines
# 0  Argentina  12/29/2020                 NaN  Sputnik V
# 1  Argentina  12/30/2020             15656.0  Sputnik V
# 2  Argentina  12/31/2020             15656.0  Sputnik V
# 3  Argentina    1/1/2021             11070.0  Sputnik V
# 4  Argentina    1/2/2021              8776.0  Sputnik V

# %%
data.isnull().sum()
# Out:
# country                0
# date                   0
# daily_vaccinations    60
# vaccines               0
# dtype: int64

# %%
data = data.fillna(0)

# %%
data.iloc[77]
# Out:
# country                       Belgium
# date                       12/28/2020
# daily_vaccinations                0.0
# vaccines              Pfizer/BioNTech
# Name: 77, dtype: object

# %%
data.groupby("country")

# %%
data["country"].unique()
# Out:
# array(['Argentina', 'Austria', 'Bahrain', 'Belgium', 'Brazil', 'Bulgaria',
#        'Canada', 'Chile', 'China', 'Costa Rica', 'Croatia', 'Cyprus',
#        'Czechia', 'Denmark', 'Ecuador', 'England', 'Estonia', 'Finland',
#        'France', 'Germany', 'Gibraltar', 'Greece', 'Hungary', 'Iceland',
#        'India', 'Indonesia', 'Ireland', 'Isle of Man', 'Israel', 'Italy',
#        'Kuwait', 'Latvia', 'Lithuania', 'Luxembourg', 'Malta', 'Mexico',
#        'Netherlands', 'Northern Ireland', 'Norway', 'Oman', 'Panama',
#        'Poland', 'Portugal', 'Romania', 'Russia', 'Saudi Arabia',
#        'Scotland', 'Serbia', 'Seychelles', 'Singapore', 'Slovakia',
#        'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'Turkey',
#        'United Arab Emirates', 'United Kingdom', 'United States', 'Wales'],
#       dtype=object)

# %%
data = data.sort_values("daily_vaccinations")

# %%
data.iloc[720]
# Out:
# country                                Czechia
# date                                  1/9/2021
# daily_vaccinations                      4832.0
# vaccines              Moderna, Pfizer/BioNTech
# Name: 337, dtype: object

# %%
country_median =data.groupby("country").median()

# %%
country_median=country_median.sort_values("daily_vaccinations",ascending=False)

# %%
country_median
# Out:
#                       daily_vaccinations
# country
# United States                   378253.0
# China                           276786.0
# India                           173922.0
# Turkey                          150356.0
# United Kingdom                  120409.0
# England                         107310.5
# Israel                           92587.0
# United Arab Emirates             86430.0
# Spain                            55238.0
# Germany                          51184.0
# Italy                            44475.5
# France                           41496.0
# Russia                           23563.0
# Poland                           22702.5
# Brazil                           17220.0
# Saudi Arabia                     16807.5
# Indonesia                        13200.0
# Romania                          13030.0
# Argentina                        11645.0
# Canada                           11044.0
# Austria                           7850.0
# Denmark                           7095.5
# ...

# %%
data = pd.read_csv("country_vaccination_stats.csv")

# %%
null_index=data[data["daily_vaccinations"].isnull()==True].index

# %%
null_index
# Out:
# Int64Index([   0,   28,   48,   77,  103,  113,  141,  184,  217,  254,  280,
#              307,  324,  354,  384,  386,  422,  451,  477,  499,  528,  543,
#              572,  600,  627,  638,  652,  677,  682,  720,  750,  751,  780,
#              812,  838,  866,  899,  916,  959,  988, 1016, 1022, 1050, 1079,
#             1108, 1138, 1150, 1193, 1211, 1226, 1238, 1256, 1278, 1300, 1322,
#             1352, 1365, 1386, 1422, 1459],
#            dtype='int64')

# %%
country_median.loc["Turkey"]["daily_vaccinations"]
# Out:
# 150356.0

# %%
for index in null_index:
    sehir = data.iloc[index]["country"]
    data["daily_vaccinations"].iloc[index] = country_median.loc[sehir]["daily_vaccinations"]
# Out:
# C:\Users\ALPPC\anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
data.iloc[48]
# Out:
# country                                  Bahrain
# date                                  12/23/2020
# daily_vaccinations                        3662.0
# vaccines              Pfizer/BioNTech, Sinopharm
# Name: 48, dtype: object

# %%
data.head(50)
# Out:
#       country        date  daily_vaccinations                    vaccines
# 0   Argentina  12/29/2020             11645.0                   Sputnik V
# 1   Argentina  12/30/2020             15656.0                   Sputnik V
# 2   Argentina  12/31/2020             15656.0                   Sputnik V
# 3   Argentina    1/1/2021             11070.0                   Sputnik V
# 4   Argentina    1/2/2021              8776.0                   Sputnik V
# 5   Argentina    1/3/2021              7400.0                   Sputnik V
# 6   Argentina    1/4/2021              6483.0                   Sputnik V
# 7   Argentina    1/5/2021              7984.0                   Sputnik V
# 8   Argentina    1/6/2021              8173.0                   Sputnik V
# 9   Argentina    1/7/2021              8363.0                   Sputnik V
# 10  Argentina    1/8/2021             10519.0                   Sputnik V
# 11  Argentina    1/9/2021             11942.0                   Sputnik V
# ...
