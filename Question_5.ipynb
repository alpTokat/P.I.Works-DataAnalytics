# %%
import pandas as pd
import numpy as np
import statistics

# %%
data = pd.read_csv("country_vaccination_stats.csv")

# %%
data.columns
# Out:
# Index(['country', 'date', 'daily_vaccinations', 'vaccines'], dtype='object')

# %%
data.head()
# Out:
#      country        date  daily_vaccinations   vaccines
# 0  Argentina  12/29/2020                 NaN  Sputnik V
# 1  Argentina  12/30/2020             15656.0  Sputnik V
# 2  Argentina  12/31/2020             15656.0  Sputnik V
# 3  Argentina    1/1/2021             11070.0  Sputnik V
# 4  Argentina    1/2/2021              8776.0  Sputnik V

# %%
data.isnull().sum()
# Out:
# country                0
# date                   0
# daily_vaccinations    60
# vaccines               0
# dtype: int64

# %%
data = data.fillna(0)

# %%
data
# Out:
#         country        date  daily_vaccinations  \
# 0     Argentina  12/29/2020                 0.0
# 1     Argentina  12/30/2020             15656.0
# 2     Argentina  12/31/2020             15656.0
# 3     Argentina    1/1/2021             11070.0
# 4     Argentina    1/2/2021              8776.0
# ...         ...         ...                 ...
# 1497      Wales   1/20/2021             11105.0
# 1498      Wales   1/21/2021             12318.0
# 1499      Wales   1/22/2021             15148.0
# 1500      Wales   1/23/2021             17371.0
# 1501      Wales   1/24/2021             17063.0
#
#                                  vaccines
# 0                               Sputnik V
# 1                               Sputnik V
# 2                               Sputnik V
# 3                               Sputnik V
# 4                               Sputnik V
# ...                                   ...
# 1497  Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
data.groupby("country")

# %%
data["country"].unique()
# Out:
# array(['Argentina', 'Italy', 'Israel', 'Isle of Man', 'Ireland',
#        'Indonesia', 'India', 'Iceland', 'Hungary', 'Greece', 'Gibraltar',
#        'Germany', 'France', 'Finland', 'Estonia', 'England', 'Ecuador',
#        'Denmark', 'Czechia', 'Cyprus', 'Croatia', 'Costa Rica', 'China',
#        'Chile', 'Canada', 'Bulgaria', 'Latvia', 'Brazil', 'Lithuania',
#        'Malta', 'Wales', 'United States', 'United Kingdom',
#        'United Arab Emirates', 'Turkey', 'Switzerland', 'Sweden', 'Spain',
#        'Slovenia', 'Slovakia', 'Singapore', 'Seychelles', 'Serbia',
#        'Scotland', 'Saudi Arabia', 'Russia', 'Romania', 'Portugal',
#        'Poland', 'Panama', 'Oman', 'Norway', 'Northern Ireland',
#        'Netherlands', 'Mexico', 'Luxembourg', 'Belgium', 'Kuwait',
#        'Bahrain', 'Austria'], dtype=object)

# %%
data = data.sort_values("daily_vaccinations")

# %%
country_median =data.groupby("country").median()

# %%
country_median=country_median.sort_values("daily_vaccinations",ascending=False)

# %%
country_median
# Out:
#                       daily_vaccinations
# country
# United States                   378253.0
# China                           276786.0
# India                           173922.0
# Turkey                          150356.0
# United Kingdom                  120409.0
# England                         107310.5
# Israel                           92587.0
# United Arab Emirates             86430.0
# Spain                            55238.0
# Germany                          51184.0
# Italy                            44475.5
# France                           41496.0
# Russia                           23563.0
# Poland                           22702.5
# Brazil                           17220.0
# Saudi Arabia                     16807.5
# Indonesia                        13200.0
# Romania                          13030.0
# Argentina                        11645.0
# Canada                           11044.0
# Austria                           7850.0
# Denmark                           7095.5
# ...

# %%
country_median.head(3)
# Out:
#                daily_vaccinations
# country
# United States            378253.0
# China                    276786.0
# India                    173922.0
